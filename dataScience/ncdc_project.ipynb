# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('ncdc.csv')

data['Survival Rate'] = np.round((data['Discharged']/ data['On admission']) *100)#to add new column /row
data.head()
# Out:
#   States Affected  Lab Confirmed  On admission  Discharged  Deaths  \
# 0           Lagos           5767          4756         944      67
# 1            Kano            999           501         450      48
# 2             FCT            952           664         265      23
# 3             Edo            401           268         109      24
# 4         Katsina            395           176         199      20
#
#    Survival Rate
# 0           20.0
# 1           90.0
# 2           40.0
# 3           41.0
# 4          113.0

# %%
sum(data["Discharged"])
# Out:
# 3959

# %%
lagos = np.std([data['Deaths']])

# %%
fig = plt.figure(figsize=[20,7])
sns.barplot(data['States Affected'],data['Survival Rate'],data=data)

plt.tight_layout()
plt.style.use('fivethirtyeight')

# %%
pl
