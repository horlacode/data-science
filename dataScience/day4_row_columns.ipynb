# %%
import pandas as pd

# %%
df = pd.read_csv('npl.csv')

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
#to get a selected line

df.iloc[3]
# Out:
# Name           R.J. Hunter
# Team        Boston Celtics
# Number                  28
# Position                SG
# Age                     22
# Height               5-Jun
# Weight                 185
# College      Georgia State
# Salary         1.14864e+06
# Name: 3, dtype: object

# %%
#to retrieve multiple columns
df[['Name','Position']]
# Out:
#               Name Position
# 0    Avery Bradley       PG
# 1      Jae Crowder       SF
# 2     John Holland       SG
# 3      R.J. Hunter       SG
# 4    Jonas Jerebko       PF
# ..             ...      ...
# 452     Trey Lyles       PF
# 453   Shelvin Mack       PG
# 454      Raul Neto       PG
# 455   Tibor Pleiss        C
# 456    Jeff Withey        C
#
# [457 rows x 2 columns]

# %%
#to retrieve multiple rows
df.iloc[5]
# Out:
# Name          Amir Johnson
# Team        Boston Celtics
# Number                  90
# Position                PF
# Age                     29
# Height               9-Jun
# Weight                 240
# College                NaN
# Salary             1.2e+07
# Name: 5, dtype: object

# %%
items = [
    ['Mango','Orange','Apple'],
    ['Cassava','Yam','Cocoyam'],
    ['Pumpkin','Okro','Others']
    
]
ind = ['fruit','tuber','vege']

# %%
df_ser = pd.DataFrame(data=items,index=ind)

# %%
df_ser
# Out:
#              0       1        2
# fruit    Mango  Orange    Apple
# tuber  Cassava     Yam  Cocoyam
# vege   Pumpkin    Okro   Others

# %%
df_ser.loc[['fruit','vege']]
# Out:
#              0       1       2
# fruit    Mango  Orange   Apple
# vege   Pumpkin    Okro  Others

# %%
#to display the first five info
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df['Salary'][1]
# Out:
# 6796117.0

# %%
#to retrieve age greater than 27 using condition
df[df['Age']>27]
# Out:
#                  Name                    Team  Number Position  Age  Height  \
# 4       Jonas Jerebko          Boston Celtics       8       PF   29  10-Jun
# 5        Amir Johnson          Boston Celtics      90       PF   29   9-Jun
# 17    Wayne Ellington           Brooklyn Nets      21       SG   28   4-Jun
# 19       Jarrett Jack           Brooklyn Nets       2       PG   32   3-Jun
# 23        Brook Lopez           Brooklyn Nets      11        C   28  Jul-00
# ..                ...                     ...     ...      ...  ...     ...
# 433  Gerald Henderson  Portland Trail Blazers       9       SG   28   5-Jun
# 434       Chris Kaman  Portland Trail Blazers      35        C   34  Jul-00
# 440     Brian Roberts  Portland Trail Blazers       2       PG   30   1-Jun
# 442     Trevor Booker               Utah Jazz      33       PF   28   8-Jun
# 450        Joe Ingles               Utah Jazz       2       SF   28   8-Jun
#
#      Weight           College      Salary
# ...

# %%
df[df['Weight']>=250]
# Out:
#                 Name                    Team  Number Position  Age  Height  \
# 10   Jared Sullinger          Boston Celtics       7        C   24   9-Jun
# 14      Tyler Zeller          Boston Celtics      44        C   26  Jul-00
# 23       Brook Lopez           Brooklyn Nets      11        C   28  Jul-00
# 38       Robin Lopez         New York Knicks       8        C   28  Jul-00
# 39      Kyle O'Quinn         New York Knicks       9       PF   26  10-Jun
# ..               ...                     ...     ...      ...  ...     ...
# 419     Mitch McGary   Oklahoma City Thunder      33       PF   24  10-Jun
# 420    Nazr Mohammed   Oklahoma City Thunder      13        C   38  10-Jun
# 434      Chris Kaman  Portland Trail Blazers      35        C   34  Jul-00
# 446   Derrick Favors               Utah Jazz      15       PF   24  10-Jun
# 455     Tibor Pleiss               Utah Jazz      21        C   26   3-Jul
#
#      Weight           College      Salary
# ...

# %%
#to check for two category
df[(df['Team']=='Boston Celtics') | (df['Age']>=25)]
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 450     Joe Ingles       Utah Jazz       2       SF   28   8-Jun     226
# 451  Chris Johnson       Utah Jazz      23       SF   26   6-Jun     206
# 453   Shelvin Mack       Utah Jazz       8       PG   26   3-Jun     203
# 455   Tibor Pleiss       Utah Jazz      21        C   26   3-Jul     256
# 456    Jeff Withey       Utah Jazz      24        C   26  Jul-00     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df[(df['Team']=='Boston Celtics') & (df['Age']>=25)]
# Out:
#              Name            Team  Number Position  Age  Height  Weight  \
# 0   Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1     Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2    John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 4   Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# 5    Amir Johnson  Boston Celtics      90       PF   29   9-Jun     240
# 7    Kelly Olynyk  Boston Celtics      41        C   25  Jul-00     238
# 11  Isaiah Thomas  Boston Celtics       4       PG   27   9-May     185
# 12    Evan Turner  Boston Celtics      11       SG   27   7-Jun     220
# 14   Tyler Zeller  Boston Celtics      44        C   26  Jul-00     253
#
#               College      Salary
# 0               Texas   7730337.0
# 1           Marquette   6796117.0
# 2   Boston University         NaN
# 4                 NaN   5000000.0
# 5                 NaN  12000000.0
# 7             Gonzaga   2165160.0
# ...

# %%
#to temporary delete a column
#df.drop('Height',axis= 1)

#to confirm you want to permanently to delete a column
df.drop('Height',axis= 1, inplace=True)

# %%
df
# Out:
#               Name            Team  Number Position  Age  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     235
# 2     John Holland  Boston Celtics      30       SG   27     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     231
# ..             ...             ...     ...      ...  ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26     203
# 454      Raul Neto       Utah Jazz      25       PG   24     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     256
# 456    Jeff Withey       Utah Jazz      24        C   26     231
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        NaN
# 3        Georgia State  1148640.0
# ...

# %%
#to create a new column
import numpy as np

# %%
np.random.seed(3)
ran = np.random.randint(4,8,457)

# %%
df['Length'] = ran

# %%
df
# Out:
#               Name            Team  Number Position  Age  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     235
# 2     John Holland  Boston Celtics      30       SG   27     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     231
# ..             ...             ...     ...      ...  ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26     203
# 454      Raul Neto       Utah Jazz      25       PG   24     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     256
# 456    Jeff Withey       Utah Jazz      24        C   26     231
#
#                College     Salary  Lenght  Length
# 0                Texas  7730337.0       6       6
# 1            Marquette  6796117.0       4       4
# ...

# %%
df.drop('Lenght',axis= 1, inplace=True)

# %%
df
# Out:
#               Name            Team  Number Position  Age  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     235
# 2     John Holland  Boston Celtics      30       SG   27     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     231
# ..             ...             ...     ...      ...  ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26     203
# 454      Raul Neto       Utah Jazz      25       PG   24     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     256
# 456    Jeff Withey       Utah Jazz      24        C   26     231
#
#                College     Salary  Length
# 0                Texas  7730337.0       6
# 1            Marquette  6796117.0       4
# 2    Boston University        NaN       5
# ...

# %%
#to delete a row
df.drop(1, inplace=True)

# %%
df
# Out:
#               Name            Team  Number Position  Age  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     180
# 2     John Holland  Boston Celtics      30       SG   27     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     231
# 5     Amir Johnson  Boston Celtics      90       PF   29     240
# ..             ...             ...     ...      ...  ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26     203
# 454      Raul Neto       Utah Jazz      25       PG   24     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     256
# 456    Jeff Withey       Utah Jazz      24        C   26     231
#
#                College      Salary  Length
# 0                Texas   7730337.0       6
# 2    Boston University         NaN       5
# 3        Georgia State   1148640.0       7
# ...

# %%
#to divide btw two row or columns
df['BMI'] =  df['Weight'] / df['Length']

# %%
df
# Out:
#               Name            Team  Number Position  Age  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     180
# 2     John Holland  Boston Celtics      30       SG   27     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     231
# 5     Amir Johnson  Boston Celtics      90       PF   29     240
# ..             ...             ...     ...      ...  ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26     203
# 454      Raul Neto       Utah Jazz      25       PG   24     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     256
# 456    Jeff Withey       Utah Jazz      24        C   26     231
#
#                College      Salary  Length        BMI
# 0                Texas   7730337.0       6  30.000000
# 2    Boston University         NaN       5  41.000000
# ...

# %%
#to read html 


pd.read_html('C:\Users\USER\Documents\covid\ncdc.html')
# Out:
#   File "<ipython-input-97-2c37122672c6>", line 4
#     pd.read_html('C:\Users\USER\Documents\covid\ncdc.html')
#                 ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
