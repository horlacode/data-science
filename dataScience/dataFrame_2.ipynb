# %%
import pandas as pd


df = pd.read_csv('npl.csv')

# %%
df.head(8)
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# 5   Amir Johnson  Boston Celtics      90       PF   29   9-Jun     240
# 6  Jordan Mickey  Boston Celtics      55       PF   21   8-Jun     235
# 7   Kelly Olynyk  Boston Celtics      41        C   25  Jul-00     238
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# 4                NaN   5000000.0
# 5                NaN  12000000.0
# 6                LSU   1170960.0
# 7            Gonzaga   2165160.0

# %%
#to delete a row
df.drop('Height',axis= 1, inplace=True)

# %%
df
# Out:
#               Name            Team  Number Position  Age  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     235
# 2     John Holland  Boston Celtics      30       SG   27     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     231
# ..             ...             ...     ...      ...  ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26     203
# 454      Raul Neto       Utah Jazz      25       PG   24     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     256
# 456    Jeff Withey       Utah Jazz      24        C   26     231
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        NaN
# 3        Georgia State  1148640.0
# ...

# %%
df['Position'][8]
# Out:
# 'PG'

# %%
#convert the weight to 

fg = df['Weight']*0.45

# %%
fg
# Out:
# 0       81.00
# 1      105.75
# 2       92.25
# 3       83.25
# 4      103.95
#         ...
# 452    105.30
# 453     91.35
# 454     80.55
# 455    115.20
# 456    103.95
# Name: Weight, Length: 457, dtype: float64

# %%
df['Weight'] = fg

# %%
df
# Out:
#               Name            Team  Number Position  Age  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25   81.00
# 1      Jae Crowder  Boston Celtics      99       SF   25  105.75
# 2     John Holland  Boston Celtics      30       SG   27   92.25
# 3      R.J. Hunter  Boston Celtics      28       SG   22   83.25
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  103.95
# ..             ...             ...     ...      ...  ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  105.30
# 453   Shelvin Mack       Utah Jazz       8       PG   26   91.35
# 454      Raul Neto       Utah Jazz      25       PG   24   80.55
# 455   Tibor Pleiss       Utah Jazz      21        C   26  115.20
# 456    Jeff Withey       Utah Jazz      24        C   26  103.95
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        NaN
# 3        Georgia State  1148640.0
# ...

# %%
#to drop the row that as NAN in it 
df.dropna(inplace=True)

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age  Weight        College  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   81.00          Texas
# 1    Jae Crowder  Boston Celtics      99       SF   25  105.75      Marquette
# 3    R.J. Hunter  Boston Celtics      28       SG   22   83.25  Georgia State
# 6  Jordan Mickey  Boston Celtics      55       PF   21  105.75            LSU
# 7   Kelly Olynyk  Boston Celtics      41        C   25  107.10        Gonzaga
#
#       Salary
# 0  7730337.0
# 1  6796117.0
# 3  1148640.0
# 6  1170960.0
# 7  2165160.0

# %%
dg = max(df['Salary'])

# %%
dg
# Out:
# 22875000.0

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-c9845f1ba750> in <module>
# ----> 1 dg.mean()
#
# AttributeError: 'float' object has no attribute 'mean'

# %%
df['Name'].unique
# Out:
# <bound method Series.unique of 0      Avery Bradley
# 1        Jae Crowder
# 3        R.J. Hunter
# 6      Jordan Mickey
# 7       Kelly Olynyk
#            ...
# 449      Rodney Hood
# 451    Chris Johnson
# 452       Trey Lyles
# 453     Shelvin Mack
# 456      Jeff Withey
# Name: Name, Length: 364, dtype: object>

# %%
#to get the age from 22 - 25
df[(df['Age'] >= 22) & (df['Age'] <= 25) & (df['Weight']>=81) & (df['Weight']<=83)]
# Out:
#               Name            Team  Number Position  Age  Weight College  \
# 0    Avery Bradley  Boston Celtics       0       PG   25    81.0   Texas
# 210      Joe Young  Indiana Pacers       1       PG   23    81.0  Oregon
#
#         Salary
# 0    7730337.0
# 210  1007026.0
