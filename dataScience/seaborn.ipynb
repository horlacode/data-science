# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
sns.set(style='darkgrid')#there is dark,white,white grid, dark grid

# %%
#seaborn comes with preloaded data
tip = sns.load_dataset('tips')

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(tips['tip'])

# %%
#countplot : shows counts of different categories
sns.countplot(tip['sex'])

# %%
sns.countplot(tip['day'])

# %%
sns.countplot(tip['time'])

# %%
fig = plt.figure(figsize=(7,7))
sns.violinplot(x=tip['sex'],y=tip['total_bill'],data=tip,palete='terrain',hue='time',split=True)
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.stripplot(x=tip['sex'],y=tip['tip'],data=tip)
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.swarmplot(x=tips['sex'],y=tip['tip'])
plt.show()

# %%
sns.catplot(x=tips['sex'],y=tips['tip'],kind='violin')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-1c3c46e1aade> in <module>
# ----> 1 sns.catplot(x=tips['sex'],y=tips['tip'],kind='violin')
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3750
#    3751     # Initialize the facets
# -> 3752     g = FacetGrid(**facet_kws)
#    3753
#    3754     # Draw the plot onto the facets
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in __init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws, size)
# ...

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(x=tips['sex'],y=tip['tip'])
plt.show()

# %%
flights = sns.load_dataset('flights')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# ~\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1243         """Send a complete request to the server."""
# -> 1244         self._send_request(method, url, body, headers, encode_chunked)
#    1245
#
# ~\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1289             body = _encode(body, 'body')
# -> 1290         self.endheaders(body, encode_chunked=encode_chunked)
#    1291
#
# ...

# %%
n = pd.read_csv('exchange.csv')
n2 = n[(n['Rate Year']>2005)&(n['Rate Year']<2010)]
usd = n2[n2['Currency']=='US DOLLAR']

USD = usd[['Rate Year','Rate Month','Buying Rate']]
pv = USD.pivot_table(index='Rate Year',columns='Rate Month',values='Buying Rate')

# %%
fig = plt.figure(figsize=(12,8))
sns.heatmap(pv)

# %%
sns.clustermap(pv)
