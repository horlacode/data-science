# %%
import pandas as pd

# %%
pd.read_html('ncdcgov.html')
# Out:
# [   States Affected  No. of Cases (Lab Confirmed)  No. of Cases (on admission)  \
#  0            Lagos                          4943                         4064
#  1             Kano                           954                          669
#  2              FCT                           660                          459
#  3          Katsina                           364                          282
#  4              Oyo                           292                          189
#  5              Edo                           284                          202
#  6             Ogun                           278                          120
#  7            Borno                           271                           78
#  8           Jigawa                           270                          130
#  9           Kaduna                           258                           93
#  10          Bauchi                           238                           10
# ...

# %%
pd.read_csv('ridwan.csv')
# Out:
#    States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# 0            Lagos                        5,767                       4,756
# 1             Kano                          999                         501
# 2              FCT                          952                         664
# 3              Edo                          401                         268
# 4          Katsina                          395                         176
# 5              Oyo                          365                         246
# 6            Borno                          356                         142
# 7             Ogun                          355                         156
# 8           Kaduna                          343                         127
# 9           Rivers                          332                         175
# 10          Bauchi                          291                          58
# ...
